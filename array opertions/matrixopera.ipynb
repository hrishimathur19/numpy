# %%
import numpy as np

# %%
A = np.array([[1,2],[4,5]])
B = np.array([[5,6],[7,8]])

# %%
A
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
B
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
A @ B
# Out:
# array([[19, 22],
#        [55, 64]])

# %%
A.T
# Out:
# array([[1, 4],
#        [2, 5]])

# %%
B.T
# Out:
# array([[5, 7],
#        [6, 8]])
