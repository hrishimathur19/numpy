# %%
import numpy as np

# %%
arr = np.arange(1,11)

# %%
bool_index = arr %2 == 0

# %%
bool_index
# Out:
# array([False,  True, False,  True, False,  True, False,  True, False,
#         True])

# %%
arr = arr[bool_index]

# %%
arr
# Out:
# array([ 2,  4,  6,  8, 10])
